# %%
age = [24, 25, 26, 27, 28]

print(age)
# Out:
# [24, 25, 26, 27, 28]

# %%
name= ["farhana","mariam","rahul","jhon","athul"]
print(name)
# Out:
# ['farhana', 'mariam', 'rahul', 'jhon', 'athul']

# %%
name.append("yazhini")
print(name)
# Out:
# ['farhana', 'mariam', 'rahul', 'jhon', 'athul', 'yazhini']

# %%
age.insert(2,30)
print(age)
# Out:
# [24, 25, 30, 26, 27, 28]

# %%
name.remove("yazhini")
print(name)
# Out:
# ['farhana', 'mariam', 'rahul', 'jhon', 'athul']

# %%
age.pop()
print(age)
# Out:
# [24, 25, 30, 26, 27]

# %%
age.extend([29,30,26])
print(age)
# Out:
# [24, 25, 30, 26, 27, 29, 20, 26, 29, 30, 26]

# %%
age.sort(reverse=True)
print(age)
# Out:
# [30, 30, 29, 29, 27, 26, 26, 26, 25, 24, 20]

# %%
print("maximum age:",max(age))
print("minimum age:",min(age))
print("sum of ages:",sum(age))
# Out:
# maximum age: 30
# minimum age: 20
# sum of ages: 292

# %%
print(name[0])
# Out:
# farhana

# %%
print(name[-1])
# Out:
# athul

# %%
print(name[2:5])
# Out:
# ['rahul', 'jhon', 'athul']

# %%
print(name[::-1])
# Out:
# ['athul', 'jhon', 'rahul', 'mariam', 'farhana']

# %%
studentmarks = {
    "Anu": 75,
    "Farhana": 88,
    "Janani": 92,
    "Rahul": 68,
    "Aisha": 81
}

print(studentmarks)
# Out:
# {'Anu': 75, 'Farhana': 88, 'Janani': 92, 'Rahul': 68, 'Aisha': 81}

# %%
print(studentmarks["Farhana"])
# Out:
# 88

# %%
studentmarks["Janani"] = 80

print(studentmarks)
# Out:
# {'Anu': 75, 'Farhana': 88, 'Janani': 80, 'Rahul': 68, 'Aisha': 81}

# %%
studentmarks["Farhana"]=82
print(studentmarks)
# Out:
# {'Anu': 75, 'Farhana': 82, 'Janani': 80, 'Rahul': 68, 'Aisha': 81}

# %%
print("keys:",studentmarks.keys())
print("values:",studentmarks.values())
print("items:",studentmarks.items())
# Out:
# keys: dict_keys(['Anu', 'Farhana', 'Janani', 'Rahul', 'Aisha'])
# values: dict_values([75, 82, 80, 68, 81])
# items: dict_items([('Anu', 75), ('Farhana', 82), ('Janani', 80), ('Rahul', 68), ('Aisha', 81)])

# %%
my_set={'a','e','i','o','u','a','a','i'}
print(my_set)
# Out:
# {'u', 'a', 'e', 'o', 'i'}

# %%
my_set.add('s')
print(my_set)                   ("GOT AN ERROR DUE TO THAT A SET HAS NO INDEX")
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /tmp/ipykernel_3789/726852993.py in <cell line: 0>()
# ----> 1 my_set[4] = 's'
#
# TypeError: 'set' object does not support item assignment

# %%
my_set.add("s")
print(my_set)
# Out:
# {'u', 's', 'a', 'e', 'o', 'i'}

# %%
set1 = {1, 3, 5, 7, 9}

set2 = {2, 3, 5, 8, 10}

print("Set 1:", set1)
print("Set 2:", set2)
# Out:
# Set 1: {1, 3, 5, 7, 9}
# Set 2: {2, 3, 5, 8, 10}

# %%
union_set=set1.union(set2)
intersection_set=set1.intersection(set2)
print("union:",union_set)
print("intersection:",intersection_set)
# Out:
# union: {1, 2, 3, 5, 7, 8, 9, 10}
# intersection: {3, 5}

# %%
score = int(input("Enter your score (0 to 10): "))

print(score)
# Out:
# Enter your score (0 to 10): 8
# 8

# %%
if score >7:
   print("above average: good efort,keep practicing")
elif score >4:
   print("below average: need to improve")
else:
   print("average:good effort,try more")
# Out:
# above average: good efort,keep practicing
