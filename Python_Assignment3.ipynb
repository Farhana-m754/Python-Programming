# %%
import random
secret_number=random.randint(1,10)
attempts=3
while attempts >0:
    guess=int(input("guess the secret_number(between 1 and 10.):"))

    if guess<1 or guess > 10:
        print("invalid guess.please enter a number between 1 and 10.")
        continue
    if guess > secret_number:
        print("too high, try again.")
    elif guess < secret_number:
          print("too low , try again.")
    else:
         print("congratulation, you guessed the correct.")
         break
    attempts -= 1

else:
         print("Better luck next time!")
# Out:
# guess the secret_number(between 1 and 10.):7
# too high, try again.
# guess the secret_number(between 1 and 10.):6
# too high, try again.
# guess the secret_number(between 1 and 10.):3
# too high, try again.
# Better luck next time!

# %%
n=int(input("enter a number "))
for i in range(1,11):
    result=n*i
    print(n, "x", i, "=", result)
# Out:
# enter a number 5
# 5 x 1 = 5
# 5 x 2 = 10
# 5 x 3 = 15
# 5 x 4 = 20
# 5 x 5 = 25
# 5 x 6 = 30
# 5 x 7 = 35
# 5 x 8 = 40
# 5 x 9 = 45
# 5 x 10 = 50

# %%
def calculate_bmi(weight, height):
    bmi = weight / (height ** 2)
    return bmi

weight = float(input("Enter your weight in kg: "))
height = float(input("Enter your height in meters: "))

bmi = calculate_bmi(weight, height)

print("Your BMI is:", round(bmi, 2))
# Out:
# Enter your weight in kg: 56
# Enter your height in meters: 1.62
# Your BMI is: 21.34
