# %%
a="Hello"
name=(" Farhana.M")
b=a+name
print(b)
# Out:
# Hello Farhana.M

# %%
c=", Welcome to Python Programming"
d=b+c
print(d)
# Out:
# Hello Farhana.M, Welcome to Python Programming

# %%
t="Hello Zara, Welcome to PYthon Programming"
print(t[0])
# Out:
# H

# %%
print(t[-1])
# Out:
# g

# %%
print(t[0:5])
# Out:
# Hello

# %%
print(t[-11:])
# Out:
# Programming

# %%
print(t[::-1])
# Out:
# gnimmargorP nohtYP ot emocleW ,araZ olleH

# %%
print(t[23:29])
# Out:
# PYthon

# %%
strM=" python beginner tutorial"
print(strM.upper())
# Out:
#  PYTHON BEGINNER TUTORIAL

# %%
print(strM.lower())
# Out:
#  python beginner tutorial

# %%
print(strM.capitalize())
# Out:
#  python beginner tutorial

# %%
print(strM.count('t'))
# Out:
# 3

# %%
print(strM.replace("python","machine learning"))
# Out:
#  machine learning beginner tutorial

# %%
tuple1=(10,20,30)
tuple2=(40,50,60)
t_combine=tuple1+tuple2
print(t_combine)
# Out:
# (10, 20, 30, 40, 50, 60)

# %%
print(t_combine*3)
# Out:
# (10, 20, 30, 40, 50, 60, 10, 20, 30, 40, 50, 60, 10, 20, 30, 40, 50, 60)

# %%
print(t_combine[2])
# Out:
# 30

# %%
print(t_combine[0:3])
# Out:
# (10, 20, 30)

# %%
print(t_combine[-3:])
# Out:
# (40, 50, 60)
